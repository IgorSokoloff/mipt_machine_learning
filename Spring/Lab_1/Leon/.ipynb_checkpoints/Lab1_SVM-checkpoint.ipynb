# %% [markdown]
# # SVM and kernels

# %% [markdown]
# Kernels concept get adopted in variety of ML algorithms (e.g. Kernel PCA, Gaussian Processes, kNN, ...).
#
# So in this task you are to examine kernels for SVM algorithm applied to rather simple artificial datasets.
#
# To make it clear: we will work with the classification problem through the whole notebook.

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV

# %% [markdown]
# Let's generate our dataset and take a look on it.

# %%
moons_points, moons_labels = make_moons(n_samples=500, noise=0.2, random_state=42)
plt.scatter(moons_points[:, 0], moons_points[:, 1], c=moons_labels)

# %% [markdown]
# ## 1.1 Pure models.
# First let's try to solve this case with good old Logistic Regression and simple (linear kernel) SVM classifier.
#
# Train LR and SVM classifiers (choose params by hand, no CV or intensive grid search neeeded) and plot their decision regions. Calculate one preffered classification metric.
#
# Describe results in one-two sentences.
#
# _Tip:_ to plot classifiers decisions you colud use either sklearn examples ([this](https://scikit-learn.org/stable/auto_examples/neural_networks/plot_mlp_alpha.html#sphx-glr-auto-examples-neural-networks-plot-mlp-alpha-py) or any other) and mess with matplotlib yourself or great [mlxtend](https://github.com/rasbt/mlxtend) package (see their examples for details)
#
# _Pro Tip:_ wirte function `plot_decisions` taking a dataset and an estimator and plotting the results cause you want to use it several times below

# %%
params_lr = {'C': np.linspace(0.01, 1, 10),
          'solver':('newton-cg', 'lbfgs', 'sag', 'saga'), 'tol':(0.01, 0.001, 0.0001)}
params_SVC = {'kernel':('linear', 'poly', 'rbf', 'sigmoid'), 'C': np.linspace(0.01, 1, 10), }
lr = LogisticRegression() 
svm = SVC() 
clf_lr = GridSearchCV(lr, params_lr, cv=5, scoring = 'accuracy', verbose=10)
clf_lr.fit(X_train, y_train)

clf_svm = GridSearchCV(svm, params_SVC, cv=5, scoring = 'accuracy', verbose=10)
clf_svm.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.7878787878787878, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.7575757575757576, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.8615384615384616, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.796875, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.859375, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.001 .............................
# [CV]  C=0.01, solver=newton-cg, tol=0.001, score=0.7878787878787878, total=   0.0s
# ...

# %%
print(clf_lr.best_params_)
print(clf_svm.best_params_)
# Out:
# {'C': 0.78, 'solver': 'saga', 'tol': 0.01}
# {'C': 1.0, 'kernel': 'rbf'}

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from mlxtend.plotting import plot_decision_regions
import matplotlib.gridspec as gridspec
import itertools

lr = LogisticRegression(C=clf_lr.best_params_['C'], solver=clf_lr.best_params_['solver'], tol=clf_lr.best_params_['tol']) 
svm = SVC(kernel=clf_svm.best_params_['kernel'], C=clf_svm.best_params_['C']) 

X, y = moons_points, moons_labels
X_train, X_test, y_train, y_test = train_test_split(moons_points, moons_labels, test_size=.35)
gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

for clf, lab, grd in zip([lr, svm],
                         ['Logistic Regression', 'Linear kernel SVM'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X_train, y_train)
    y_predicted = clf.predict(X_test)
    
    
    #classification metrics
    from sklearn.metrics import confusion_matrix, accuracy_score
    print(confusion_matrix(y_test, y_predicted))
    
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X_test, y=y_test, clf=clf, legend=2)
    plt.title(lab)
plt.show()
# Out:
# [[74 13]
#  [15 73]]
# [[84  3]
#  [ 8 80]]

# %% [markdown]
# ## 1.2 Kernel tirck
#
# ![keep-calm](i.jpg)
#
# Now use different kernels (`poly`, `rbf`, `sigmoid`) on SVC to get better results. Play `degree` parameter and others.
#
# For each kernel estimate optimal params, plot decision regions, calculate metric you've chosen eariler.
#
# Write couple of sentences on:
#
# * What have happenned with classification quality?
# * How did decision border changed for each kernel?
# * What `degree` have you chosen and why?

# %% [markdown]
# # Answers

# %% [markdown]
# 1)  rbf kernel has higher quality than quality of sigmoid kernel(and poly from 1 to 10 degrees)
#
# 2)
#
# 3) GridSearchCV said that I should use degree = 1, but I don't think so, i think the best is 3

# %%
params_lr = {'C': np.linspace(0.01, 1, 10),
          'solver':('newton-cg', 'lbfgs', 'sag', 'saga'), 'tol':(0.01, 0.001, 0.0001)}
params_SVC = {'C': np.linspace(0.01, 1, 10), 'degree' : list(range(1,20))}
lr = LogisticRegression() 
clf_lr = GridSearchCV(lr, params_lr, cv=5, verbose=10)
clf_lr.fit(X_train, y_train)

svm_poly = SVC(kernel='poly') 
clf_svm_poly = GridSearchCV(svm_poly, params_SVC, cv=5, verbose=10)
clf_svm_poly.fit(X_train, y_train)

svm_rbf = SVC(kernel='rbf') 
clf_svm_rbf = GridSearchCV(svm_rbf, params_SVC, cv=5, verbose=10)
clf_svm_rbf.fit(X_train, y_train)

svm_sigmoid = SVC(kernel='sigmoid') 
clf_svm_sigmoid = GridSearchCV(svm_sigmoid, params_SVC, cv=5, verbose=10)
clf_svm_sigmoid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.803030303030303, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.7878787878787878, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.8307692307692308, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV]  C=0.01, solver=newton-cg, tol=0.01, score=0.859375, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.01 ..............................
# [CV] ... C=0.01, solver=newton-cg, tol=0.01, score=0.75, total=   0.0s
# [CV] C=0.01, solver=newton-cg, tol=0.001 .............................
# [CV]  C=0.01, solver=newton-cg, tol=0.001, score=0.803030303030303, total=   0.0s
# ...

# %%
print(clf_lr.best_params_, 'clf_lr')
print(clf_svm_poly.best_params_, 'clf_svm_poly')
print(clf_svm_rbf.best_params_, 'clf_svm_rbf')
print(clf_svm_sigmoid.best_params_, 'clf_svm_sigmoid')
# Out:
# {'C': 0.56, 'solver': 'saga', 'tol': 0.01} clf_lr
# {'C': 0.23, 'degree': 1} clf_svm_poly
# {'C': 0.78, 'degree': 1} clf_svm_rbf
# {'C': 0.01, 'degree': 1} clf_svm_sigmoid

# %%
X, y = moons_points, moons_labels
X_train, X_test, y_train, y_test = train_test_split(moons_points, moons_labels, test_size=.35)
svm_rbf = SVC(C=0.23,kernel='rbf')
svm_sigmoid = SVC(kernel='sigmoid')


gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

for clf, lab, grd in zip([svm_rbf, svm_sigmoid],
                         ['rbf kernel', 'sigmoid kernel'],
                         itertools.product([0, 1], repeat=2)):
    clf.fit(X_train, y_train)
    y_predicted = clf.predict(X_test)
    
    
    #classification metrics
    print('metric %s\n ' % lab, confusion_matrix(y_test, y_predicted))
    
    ax = plt.subplot(gs[grd[0], grd[1]])
    
    fig = plot_decision_regions(X=X_test, y=y_test, clf=clf, legend=2)
    plt.title(lab)
plt.show()
# Out:
# metric rbf kernel
#   [[82  3]
#  [12 78]]
# metric sigmoid kernel
#   [[57 28]
#  [34 56]]

# %%
for i in range(20):
    svm_poly = SVC(kernel='poly', degree = i, gamma='auto')
    gs = gridspec.GridSpec(2, 2)
    fig = plt.figure(figsize=(10, 8))

    for clf, lab, grd in zip([svm_poly], ['degree %s' % i], itertools.product([0, 1], repeat=2)):
        clf.fit(X_train, y_train)
        y_predicted = clf.predict(X_test)
    
    
        #classification metrics
        print('metric\n', confusion_matrix(y_test, y_predicted))
    
        ax = plt.subplot(gs[grd[0], grd[1]])
        fig = plot_decision_regions(X=X_test, y=y_test, clf=clf, legend=2)
        plt.title(lab)
    plt.show()
# Out:
# metric
#  [[85  0]
#  [90  0]]
# metric
#  [[77  8]
#  [21 69]]
# metric
#  [[57 28]
#  [22 68]]
# metric
#  [[81  4]
#  [30 60]]
# metric
#  [[80  5]
#  [49 41]]
# metric
#  [[85  0]
#  [43 47]]
# metric
#  [[84  1]
#  [47 43]]
# metric
#  [[85  0]
#  [48 42]]
# metric
#  [[85  0]
#  [51 39]]
# metric
#  [[85  0]
#  [51 39]]
# metric
#  [[85  0]
#  [54 36]]
# metric
#  [[85  0]
#  [52 38]]
# metric
#  [[85  0]
#  [55 35]]
# metric
#  [[85  0]
#  [53 37]]
# metric
#  [[85  0]
#  [57 33]]
# metric
#  [[85  0]
#  [54 36]]
# metric
#  [[85  0]
#  [57 33]]
# metric
#  [[85  0]
#  [54 36]]
# metric
#  [[85  0]
#  [55 35]]
# metric
#  [[85  0]
#  [51 39]]

# %% [markdown]
# ## 1.3 Simpler solution (of a kind)
# What is we could use Logisitc Regression to successfully solve this task?
#
# Feature generation is a thing to help here. Different techniques of feature generation are used in real life, couple of them will be covered in additional lectures.
#
# In particular case simple `PolynomialFeatures` ([link](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html)) are able to save the day.
#
# Generate the set of new features, train LR on it, plot decision regions, calculate metric.
#
# * Comare SVM's results with this solution (quality, borders type)
# * What degree of PolynomialFeatures have you used? Compare with same SVM kernel parameter.

# %%
from sklearn.preprocessing import PolynomialFeatures
for i in range(1,10): 
    poly = PolynomialFeatures(degree = i)

    X_train_ = poly.fit_transform(X_train)
    X_test_ = poly.fit_transform(X_test)
    
    lr = LogisticRegression(solver='liblinear', random_state=0) # add some params

    lr.fit(X_train_, y_train)
    y_predicted = lr.predict(X_test_)

    print('metric of degree %s\n' % i, confusion_matrix(y_test, y_predicted))
# Out:
# metric of degree 1
#  [[78  7]
#  [19 71]]
# metric of degree 2
#  [[78  7]
#  [20 70]]
# metric of degree 3
#  [[84  1]
#  [12 78]]
# metric of degree 4
#  [[85  0]
#  [10 80]]
# metric of degree 5
#  [[85  0]
#  [ 7 83]]
# metric of degree 6
#  [[85  0]
#  [ 7 83]]
# metric of degree 7
#  [[85  0]
#  [ 6 84]]
# metric of degree 8
#  [[84  1]
#  [ 6 84]]
# metric of degree 9
#  [[84  1]
#  [ 6 84]]

# %% [markdown]
# ## 1.4 Harder problem
#
# Let's make this task a bit more challenging via upgrading dataset:

# %%
from sklearn.datasets import make_circles

circles_points, circles_labels = make_circles(n_samples=500, noise=0.06, random_state=42)

plt.figure(figsize=(5, 5))
plt.scatter(circles_points[:, 0], circles_points[:, 1], c=circles_labels)

# %% [markdown]
# And even more:

# %%
points = np.vstack((circles_points*2.5 + 0.5, moons_points))
labels = np.hstack((circles_labels, moons_labels + 2)) # + 2 to distinct moons classes

plt.figure(figsize=(5, 5))
plt.scatter(points[:, 0], points[:, 1], c=labels)

# %% [markdown]
# Now do your best using all the approaches above!
#
# Tune LR with generated features, SVM with appropriate kernel of your choice. You may add some of your loved models to demonstrate their (and your) strength. Again plot decision regions, calculate metric.
#
# Justify the results in a few phrases.

# %%
X_train, X_test, y_train, y_test = train(points, labels, test_size=.30)

param_grid = {'C': np.linspace(0.01, 1, 10), 'penalty' : ['l1','l2'] }
clf = GridSearchCV(LogisticRegression(multi_class = 'multinomial', solver = 'saga'), 
                   param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1)

res = clf.fit(X_train,y_train)
print(res.best_params_)
# Out:
# {'C': 0.12, 'penalty': 'l2'}

# %%
lr = LogisticRegression(multi_class = 'auto', solver='liblinear', random_state=0, C = 0.01, penalty = 'l2')

gs = gridspec.GridSpec(1, 1)
fig = plt.figure(figsize=(10, 8))

for clf, lab, grd in zip([lr], ['Logistic Regression'], itertools.product([0, 1], repeat=2)):
    clf.fit(X_train, y_train)
    y_predicted = clf.predict(X_test)
    
    
    #classification metrics
    print('metric: \n', confusion_matrix(y_test, y_predicted), '\n Accuracy:', accuracy_score(y_test, y_predicted))
    
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X_test, y=y_test, clf=clf, legend=2)
    plt.title(lab)
plt.show()
# Out:
# metric:
#  [[ 0 12 34 36]
#  [ 0 12 25 32]
#  [ 0 20 49  9]
#  [ 0  5  3 63]]
#  Accuracy: 0.41333333333333333

# %%
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train(points, labels, test_size=.30)


param_grid = {'C': np.linspace(0.01, 10, 10)}
clf = GridSearchCV(SVC(kernel='rbf'), 
                   param_grid, cv = 5, scoring = 'accuracy', n_jobs = -1)

res = clf.fit(X_train,y_train)
print(res.best_params_)
# Out:
# {'C': 8.89}

# %%
svm_rbf = SVC(kernel='rbf', C = 2.23)

gs = gridspec.GridSpec(1, 1)
fig = plt.figure(figsize=(10, 8))

for clf, lab, grd in zip([svm_rbf], ['radial basis function'], itertools.product([0, 1], repeat=2)):
    clf.fit(X_train, y_train)
    y_predicted = clf.predict(X_test)
    
    
    #classification metrics
    print('metric:\n', confusion_matrix(y_test, y_predicted), '\n Accuracy:', accuracy_score(y_test, y_predicted))
    
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X_test, y=y_test, clf=clf, legend=2)
    plt.title(lab)
plt.show()
# Out:
# metric:
#  [[78  4  0  0]
#  [ 4 63  1  1]
#  [ 0  1 76  1]
#  [ 0  1  4 66]]
#  Accuracy: 0.9433333333333334

# %% [markdown]
# # Justify the results in a few phrases.

# %% [markdown]
# According to all above, SVM is STEEPER than LR
